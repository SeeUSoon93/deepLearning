# %% [markdown]
# <a href="https://colab.research.google.com/github/SeeUSoon93/deepLearning/blob/main/ex01_%EB%8F%99%EB%AC%BC%EB%B6%84%EB%A5%98_%EB%AA%A8%EB%8D%B8_%EB%A7%8C%EB%93%A4%EA%B8%B0(10%EA%B0%80%EC%A7%80).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 현재 작업 디렉토리 확인
# !pwd
# Out:
# /content

# %%
# 작업 디렉토리 변경
# %cd "/content/drive/MyDrive/Colab Notebooks/DeepLearning"
# Out:
# /content/drive/MyDrive/Colab Notebooks/DeepLearning

# %% [markdown]
# ### 실습목표
# - keras를 이용한 딥러닝 모델링 익숙해지기
# - 데이터로딩 > 이미지특징추출(전처리) > 학습 > 평가
# - GPU환경 활용해보기
# ![image.png](data:image/png;base64,...)

# %%
# 라이브러리, 모듈 로딩
import numpy as np
from tqdm import tqdm # 반복문 작업의 진행률을 보여주는 도구
from tensorflow.keras.utils import image_dataset_from_directory # 폴더에서 이미지를 로딩해주는 모듈(함수)

# %% [markdown]
# ### 1.데이터 로딩

# %%
# 압축풀기
# !unzip ./data/small.zip -d ./data/animal_small/
